# %%
import numpy as np
import pandas as pd
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
import re

# %%
data=pd.read_csv("Hurricane_Harvey.csv",encoding = "ISO-8859-1")
print(data.head(5))
# Out:
#   Unnamed: 0            ID  Likes  Replies  Retweets                 Time  \
# 0          0  9.011738e+17    0.0      0.0       0.0  2017-08-25 20:05:45
# 1          1  9.011738e+17    0.0      0.0       0.0  2017-08-25 20:05:46
# 2          2  9.011738e+17    0.0      0.0       0.0  2017-08-25 20:05:46
# 3          3  9.011738e+17    0.0      0.0       1.0  2017-08-25 20:05:47
# 4          4  9.011738e+17   18.0      1.0      23.0  2017-08-25 20:05:48
#
#                                                Tweet Unnamed: 0.1
# 0  Hurricane Harvey predicted to make landfall at...          NaN
# 1  Dude! Surfing never stops #hurricaneharvey #no...          NaN
# 2  Hurricane Harvey: Coldplay & Mary J. Blige Con...          NaN
# 3  .@Jeff_Piotrowski on #Periscope: Damaging wind...          NaN
# 4  Stark language from @NWS: "The flooding will b...          NaN
# ...

# %%
tknzr = TweetTokenizer()
#create a series with tweet text
data_tweet = data["Tweet"]

#Tokenize the tweet using TweetTokenizer
data_tweet = tknzr.tokenize(str(data_tweet))

#Remove the stop words
stops = set(stopwords.words("english"))
tweet_words = [w for w in data_tweet if not w in stops]

#Remove everything but the words
tweet_words = re.sub("[^a-zA-Z]"," ", str(tweet_words))

# %%
#create a wordcloud
from wordcloud import WordCloud, STOPWORDS
#wordcloud = WordCloud().generate(tweet_words)
# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
#plt.imshow(wordcloud, interpolation='bilinear')
#plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='black',
                          width=1200,
                          height=1000).generate(tweet_words)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# The pil way (if you don't have matplotlib)
# image = wordcloud.to_image()
# image.show()
